# %% [markdown]
# <a href="https://colab.research.google.com/github/ERDECE/UTS_MN/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
# !nvidia-smi
# Out:
# Sat Jan 18 14:54:20 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# clone YOLOv5 repository
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17265, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 17265 (delta 57), reused 14 (delta 14), pack-reused 17160 (from 4)
# Receiving objects: 100% (17265/17265), 16.01 MiB | 14.78 MiB/s, done.
# Resolving deltas: 100% (11799/11799), done.

# %%
# install dependencies as necessary
# !pip install -r requirements.txt
# !pip uninstall wandb -qy # deprecated dependency
import torch

from IPython.display import Image, clear_output # to display images

#clear_output()
print('setup complete. using torch %s %s' % (torch._version_, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# WARNING: Skipping wandb as it is not installed.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-55fcae3ad39f> in <cell line: 0>()
#       7
#       8 #clear_output()
# ----> 9 print('setup complete. using torch %s %s' % (torch._version_, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
#
# /usr/local/lib/python3.11/dist-packages/torch/__init__.py in __getattr__(name)
#    2560             return importlib.import_module(f".{name}", __name__)
#    2561
# -> 2562         raise AttributeError(f"module '{__name__}' has no attribute '{name}'")
#    2563
#    2564
#
# AttributeError: module 'torch' has no attribute '_version_'

# %%
# %cd /content/yolov5
# !pip install -q roboflow==1.1.48

from roboflow import Roboflow

rf = Roboflow(api_key="MWGaE79LAfhP12Vh2G2c")
project = rf.workspace("rangga-it").project("jalan-raya-soyyh")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# /content/yolov5
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to jalan-raya-1 in yolov5pytorch:: 100%|██████████| 210/210 [00:00<00:00, 8386.45it/s]

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)

# %%
# %ls runs/train/yolov5s_results/weights
# Out:
# best.pt  last.pt

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp2/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on IMG-20250114-WA0037_jpg.rf.c6c632693f107a26fb3cec0852541e91.jpg
# {'predictions': [{'x': 216.5,
#    'y': 274.0,
#    'width': 45.0,
#    'height': 102.0,
#    'confidence': 0.8443654179573059,
#    'class': 'MOBIL',
#    'class_id': 0,
#    'detection_id': '439a2df4-2473-4df0-afc3-24f875fd2899',
#    'image_path': '/content/yolov5/jalan-raya-1/test/images/IMG-20250114-WA0037_jpg.rf.c6c632693f107a26fb3cec0852541e91.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 297.5,
#    'y': 470.5,
#    'width': 85.0,
#    'height': 263.0,
#    'confidence': 0.781644880771637,
#    'class': 'MOBIL',
#    'class_id': 0,
#    'detection_id': '9d5f6f09-10ad-4fa1-9186-f68f38b0232f',
#    'image_path': '/content/yolov5/jalan-raya-1/test/images/IMG-20250114-WA0037_jpg.rf.c6c632693f107a26fb3cec0852541e91.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 186.5,
#    'y': 150.0,
#    'width': 33.0,
#    'height': 70.0,
# ...

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.35 --source jalan-raya-1/train/images/
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_results/weights/best.pt'], source=jalan-raya-1/train/images/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-397-gde62f93c Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/69 /content/yolov5/jalan-raya-1/train/images/IMG-20250114-WA0027_jpg.rf.c0a479e2d6380d98cf8407b182aa538d.jpg: 416x416 1 MOBIL, 7.1ms
# ...

# %%
# train yolov5s on custom data for 25 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py \
  --img 416 \
  --batch 16 \
  --epochs 25 \
  --data jalan-raya-1/data.yaml \
  --weights yolov5s.pt \
  --name yolov5s_results  \
  --cache
# Out:
# /content/yolov5
# 2025-01-18 15:31:05.515509: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-18 15:31:05.534481: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-18 15:31:05.540497: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
